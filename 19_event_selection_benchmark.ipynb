# %% [markdown]
# <a href="https://colab.research.google.com/github/zaetae/regime-aware-ml-trading/blob/main/19_event_selection_benchmark.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import inspect
from src.backtest.simulator import simulate_trades

print(inspect.getsource(simulate_trades))

# %%
# Pseudocode structure — will fill in with real function calls once we see simulate_trades()

# Strategy 1: ML-filtered (your actual model)
ml_trades = simulate_trades(df, events=ml_predicted_events, directions=ml_predictions, ...)

# Strategy 2: No-filter (every detected event, using its own intended_direction)
all_pattern_events = df[df['has_event']]
no_filter_trades = simulate_trades(df, events=all_pattern_events,
                                     directions=all_pattern_events['intended_direction'], ...)

# Strategy 3: Random-entry (same events, coin-flip direction)
rng = np.random.default_rng(42)
random_directions = rng.choice(['long', 'short'], size=len(all_pattern_events))
random_trades = simulate_trades(df, events=all_pattern_events, directions=random_directions, ...)

# Compare: cumulative return, Sharpe, win rate, num trades, across all three
