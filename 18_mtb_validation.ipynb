# %% [markdown]
# <a href="https://colab.research.google.com/github/zaetae/regime-aware-ml-trading/blob/main/18_mtb_validation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import inspect
from src.patterns.multiple_tops_bottoms import detect_multiple_tops_bottoms

print(inspect.getsource(detect_multiple_tops_bottoms))
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /tmp/ipykernel_735/1000800607.py in <cell line: 0>()
#       1 import inspect
# ----> 2 from src.patterns.multiple_tops_bottoms import detect_multiple_tops_bottoms
#       3
#       4 print(inspect.getsource(detect_multiple_tops_bottoms))
#
# ModuleNotFoundError: No module named 'src'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------
